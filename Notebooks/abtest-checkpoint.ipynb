# %% [markdown]
# ## AB Testing

# %%
import os
import sys
import pandas as pd
import numpy as np
sys.path.append(r"C:\Users\Admin\Desktop\Havartechs\Projects\ABTesting\abtest-mlops\scripts")
sys.path.append(os.path.abspath(os.path.join('../scripts')))
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import plotly.express as px

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import plots
import scipy.stats as scs

from helper import Helper

# %%
helper = Helper()

# %%
file_name = r'C:\Users\Admin\Desktop\Havartechs\Projects\ABTesting\abtest-mlops\data\AdSmartABdata.csv'
ad_df = pd.read_csv(file_name)
ad_df.head()
# Out:
#                              auction_id experiment        date  hour  \
# 0  0008ef63-77a7-448b-bd1e-075f42c55e39    exposed  2020-07-10     8
# 1  000eabc5-17ce-4137-8efe-44734d914446    exposed  2020-07-07    10
# 2  0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  2020-07-05     2
# 3  00187412-2932-4542-a8ef-3633901c98d9    control  2020-07-03    15
# 4  001a7785-d3fe-4e11-a344-c8735acacc2c    control  2020-07-03    15
#
#           device_make  platform_os                browser  yes  no
# 0  Generic Smartphone            6          Chrome Mobile    0   0
# 1  Generic Smartphone            6          Chrome Mobile    0   0
# 2               E5823            6  Chrome Mobile WebView    0   1
# 3   Samsung SM-A705FN            6               Facebook    0   0
# 4  Generic Smartphone            6          Chrome Mobile    0   0

# %%
print(f"number of rows: {ad_df.shape[0]}")
print(f"number of cols: {ad_df.shape[1]}")

ad_df.info()
# Out:
# number of rows: 8077
# number of cols: 9
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8077 entries, 0 to 8076
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   auction_id   8077 non-null   object
#  1   experiment   8077 non-null   object
#  2   date         8077 non-null   object
#  3   hour         8077 non-null   int64
#  4   device_make  8077 non-null   object
#  5   platform_os  8077 non-null   int64
#  6   browser      8077 non-null   object
#  7   yes          8077 non-null   int64
#  8   no           8077 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 568.0+ KB

# %% [markdown]
# ## check for the missing values

# %%
# percentage of our missing data 
print(f"Percent of missing values in our data is {helper.percent_missing(ad_df)}%")
# Out:
# Percent of missing values in our data is 0.0%

# %%
ad_df.isnull().sum()
# Out:
# auction_id     0
# experiment     0
# date           0
# hour           0
# device_make    0
# platform_os    0
# browser        0
# yes            0
# no             0
# dtype: int64

# %% [markdown]
# ## Exploration of the data

# %%
# Control and the Exposed groups 
controll_num = ad_df.groupby('experiment').agg({'auction_id': 'count'})['auction_id']['control']
exposed_num  = ad_df.groupby('experiment').agg({'auction_id': 'count'})['auction_id']['exposed']

print(f"The number of entries in control group is {controll_num}")
print(f"The number of entries in experiment group is {exposed_num}")
# Out:
# The number of entries in control group is 4071
# The number of entries in experiment group is 4006

# %%
browsers = ad_df['browser'].unique()
print(browsers)
# Out:
# ['Chrome Mobile' 'Chrome Mobile WebView' 'Facebook' 'Mobile Safari'
#  'Chrome Mobile iOS' 'Samsung Internet' 'Mobile Safari UI/WKWebView'
#  'Chrome' 'Opera Mini' 'Edge Mobile' 'Android' 'Pinterest' 'Opera Mobile'
#  'Firefox Mobile' 'Puffin']

# %%
devices = ad_df['device_make'].unique()
print(devices)
# Out:
# ['Generic Smartphone' 'E5823' 'Samsung SM-A705FN' 'Samsung SM-G960F'
#  'Samsung SM-G973F' 'iPhone' 'Samsung SM-G935F' 'HTC One' 'LG-$2'
#  'Samsung SM-A202F' 'XT1032' 'COL-L29' 'Samsung SM-N960U1'
#  'Samsung SM-A715F' 'Samsung SM-G930F' 'I3312' 'Samsung SM-G950F'
#  'FIG-LX1' 'Samsung SM-G920F' 'MRD-LX1' 'Samsung SM-N950F' 'Moto $2'
#  'Samsung SM-G970F' 'Samsung GT-I9505' 'Samsung SM-G981B' 'Pixel 3a'
#  'Samsung SM-J600FN' 'Samsung SM-A105FN' 'OnePlus ONEPLUS A3003' 'POT-LX1'
#  'Samsung SM-G975F' 'Samsung SM-J330FN' 'Samsung SM-G770F' 'H3311'
#  'MAR-LX1A' 'HTC One $2' 'Samsung SM-G965F' 'ELE-L09' 'Samsung SM-J415FN'
#  'Samsung SM-G900F' 'Lenovo A1010a20' 'CLT-L09' 'HTC Desire $2'
#  'Samsung SM-G980F' 'Samsung SM-G955F' 'Samsung SM-N960F' 'Nexus 5'
#  'Samsung SM-J260F' 'HTC U11' 'Samsung SM-A405FN' 'Samsung SM-A600FN'
#  'ANE-LX1' 'VOG-L09' 'Samsung SM-G986B' 'XiaoMi Redmi Note 4' 'ELE-L29'
#  'Samsung $2' 'Samsung SM-A320FL' 'OnePlus ONEPLUS A5000'
#  'Samsung SM-A505FN' 'Nokia undefined$2$3' 'Samsung SM-A750FN'
#  'Samsung SM-A310F' 'Samsung SM-A520F' 'OnePlus ONEPLUS A5010'
#  'Samsung SM-N975F' 'Pixel 4' 'LYA-L09' 'Samsung SM-G988B' 'VOG-L29'
#  'Samsung SM-N976B' '5008Y_EEA' 'CLT-L29' 'PRA-LX1' 'Samsung SM-J320FN'
#  'Samsung SM-J530F' 'Samsung SM-A530F' 'BKL-L09' 'Pixel 3'
#  'Samsung SM-A515F' 'Nokia$2$3' 'F8331' 'Samsung SM-A300FU'
#  'Samsung SM-G390F' 'VFD 710' 'XiaoMi Redmi 6' 'Samsung SM-G901F'
#  'OnePlus ONEPLUS A6003' 'Samsung SM-A500FU' 'Samsung SM-G900V' 'SNE-LX1'
#  'STF-L09' 'HTC 10' 'Samsung SM-J510FN' 'Samsung SM-J610FN' 'S8'
#  'XiaoMi Redmi Note 7' 'Samsung SM-G800F' 'EML-L09' 'Samsung SM-N970F'
#  'Huawei Browser' 'OnePlus ONEPLUS A6013' 'Samsung GT-I8200N'
#  'Samsung SM-A920F' 'NEM-L51' 'Samsung SM-G570F' 'Samsung SM-G925F'
#  'VFD 820' 'Asus I01WD' 'HUAWEI $2' 'OnePlus ONEPLUS A6000'
#  'Samsung SM-J710F' 'Samsung SM-G928F' 'XiaoMi Redmi 8' 'H3113' 'DUB-LX1'
#  'Pixel 2' 'Samsung GT-I9195' 'WAS-LX1A' 'F5321' 'XiaoMi MI 8 Pro'
#  'EVA-L09' 'Samsung SM-J730F' 'LYA-L29' 'VFD 500' 'YAL-L21' 'HTC U12+'
#  'Samsung SM-J330G' 'XiaoMi MI 8' 'Samsung undefined$2' 'G3311' 'G3121'
#  'DUA-L22' 'Samsung SM-G950U1' 'Samsung SM-G850F' 'Samsung GT-I9505 '
#  'Samsung SM-A107F' 'BBB100-2' 'VFD 610' 'XiaoMi Redmi 6A' '5099Y'
#  'Samsung SM-F907B' 'Samsung SM-N9500' 'D5503' 'Samsung SM-G977B'
#  'Lumia 950' 'Samsung GT-P5210 ' 'COR-L29' 'LDN-L01' 'Samsung SM-J710MN'
#  'Lenovo A7020a48' 'Samsung SM-G965U1' 'Samsung SM-N910F' 'CUBOT_X18_Plus'
#  'Samsung SM-A507FN' 'BLA-L09' 'Samsung SM-G900T' 'VTR-L09'
#  'Samsung SM-J500FN' 'moto e5 play' 'A0001' 'PCT-L29' 'Samsung SM-G925I'
#  'HTC M10h' 'Vodafone $2' 'Samsung SM-G6100' 'D5803' 'Samsung SM-A505F'
#  'Samsung SM-G986U1' 'Samsung SM-N9750' 'D6603' 'VFD 700' '6039Y'
#  'Samsung SM-N920I' 'Samsung SM-G950U' 'XiaoMi Redmi Note 8T'
#  'Samsung SM-G935U' 'Samsung SM-A105G' 'OnePlus ONE A2003'
#  'Samsung GT-I9195I' 'C2105' 'ALE-L21' 'Samsung SM-G930L' 'XT1580'
#  'Samsung SM-G973U' 'XiaoMi Redmi Note 8 Pro' 'Samsung SM-A015M'
#  'Samsung SM-G388F' 'Samsung SM-N976V' 'VFD 720' 'Samsung SM-G930U'
#  'EVR-N29' 'XiaoMi Redmi Note 8' 'F3111' 'EML-L29' 'Samsung SM-G610F'
#  'Samsung SM-A305F' 'Samsung SM-J701F' 'Samsung SM-A510F' 'IMO $2'
#  'Pixel XL' 'Samsung SM-A415F' 'Samsung SM-A217F' 'Samsung SM-A908B'
#  'BBF100-1' 'HTC U11 $2' 'E6653' 'Samsung SM-G903F' 'VKY-L09'
#  'Samsung SM-A207F' 'XiaoMi MI MAX 3' 'F3311' 'Lenovo P2a42'
#  'Samsung SM-A205G' 'Samsung SM-A605F' 'VF-795' 'VF-895N'
#  'Samsung SM-A605G' 'D6503' 'Armor_3' 'FRD-L09' 'TA-1033' 'Doro 8030'
#  'moto e5 plus' 'Samsung SM-J250F' 'Samsung SM-C9000' 'Moto$2'
#  'Samsung SM-A105F' 'ATU-L11' 'Samsung SM-N770F' 'TA-1020' 'DLI-L22'
#  'Samsung SM-A805F' 'XiaoMi Redmi Note 6 Pro' 'Samsung SM-G955U'
#  'Samsung GT-I9300' 'C6903' 'RNE-L21' 'Samsung SM-G361F' 'G3221'
#  'Samsung SM-G930T' 'Samsung SM-J510GN' 'Samsung SM-A700F' 'CPH1851' 'X13'
#  'OnePlus ONE E1003' 'Samsung SM-J810F' 'TA-1024' 'OnePlus ONEPLUS A3000'
#  'XiaoMi Redmi 3S' 'MHA-L09' 'XiaoMi MI 6' 'K7' 'Swift 2 Plus'
#  'X4_Soul_Infinity_Z' 'Samsung SM-G960U1' 'Wileyfox Swift'
#  'Samsung SM-J330F' 'PLK-L01' 'Samsung SM-A750GN' 'Samsung SM-G930V'
#  'XiaoMi Redmi 5 Plus' 'Samsung SM-J610G' 'VCE-L22' 'Samsung SM-G960U'
#  'Samsung SM-G9730' 'Samsung SM-G955U1' 'XiaoMi Redmi S2'
#  'Samsung SM-A205F' 'XiaoMi Redmi Note 5']

# %%
time = ad_df['hour'].unique()
print(time)
# Out:
# [ 8 10  2 15  5  0 14 13  6 16  7 20  4 17  1 19 18  3 23 12  9 11 21 22]

# %% [markdown]
# ## EDA of our Data

# %% [markdown]
# #### Entries in the control and the experimental group

# %%
plots.plot_count(ad_df, 'experiment')

# %%
device_df = ad_df.groupby('device_make').agg({"device_make": 'count'})
device_df = device_df.rename(columns={'device_make': "Count of device"})
device_df['device'] = device_df.index
device_df = device_df.sort_values(by="Count of device", ascending=False)

plots.plot_bar(device_df.head(10), x_col='device', y_col='Count of device',
               title="Top 10 devices in our dataset", xlabel="device", ylabel="Count of device")

# %% [markdown]
# #### Most of the device in our sample is from Generic smarthphone

# %% [markdown]
# ### The number of yes and no answers in each group

# %%
yes_no_agg = ad_df.groupby('experiment').agg({'yes': 'sum', 'no': 'sum'})
ax = yes_no_agg.plot.bar( y=['yes', 'no'],  title="The number of yes and no answers per experiment",
                          rot=0, figsize=(10,7))

# %% [markdown]
# #### The range differnce b/n the total number of yes anwers minus the total number of no answers has increased in exposed group

# %%
browser_control_df = ad_df[ad_df['experiment'] == "control"]
browser_control_df = browser_control_df[['browser', 'experiment']].sort_values(by="browser", ascending=False)
browser_control_df = browser_control_df.groupby('browser').agg({'browser': 'count'})
browser_control_df = browser_control_df.rename(columns={'browser': 'count of browsers'})
browser_control_df['browser'] = browser_control_df.index
browser_control_df = browser_control_df.sort_values(by="count of browsers", ascending=False)
plots.plot_bar(browser_control_df.head(10), x_col='browser', y_col='count of browsers',
               title="Top 10 browsers from our control group", xlabel="browser", ylabel="count of browsers")

# %%
browser_exposed_df = ad_df[ad_df['experiment'] == "exposed"]
browser_exposed_df = browser_exposed_df[['browser', 'experiment']].sort_values(by="browser", ascending=False)
browser_exposed_df = browser_exposed_df.groupby('browser').agg({'browser': 'count'})
browser_exposed_df = browser_exposed_df.rename(columns={'browser': 'count of browsers'})
browser_exposed_df['browser'] = browser_exposed_df.index
browser_exposed_df = browser_exposed_df.sort_values(by="count of browsers", ascending=False)
plots.plot_bar(browser_exposed_df.head(10), x_col='browser', y_col='count of browsers',
               title="Top 10 browsers from our control group", xlabel="browser", ylabel="count of browsers")

# %% [markdown]
# ### The hour distribution of the experiment

# %%
exposed_group = ad_df[ad_df['experiment'] == 'exposed']
plots.plot_dist(exposed_group['hour'], 'Hour in exposed group')

# %% [markdown]
# The hour of the experiment for exposed group seems evenly distributed

# %%
control_group = ad_df[ad_df['experiment'] == 'control']
plots.plot_dist(control_group['hour'], 'Hour in exposed group')

# %% [markdown]
# Most of the conrol group data was taken around 15 hr

# %%
data = ad_df.copy()

# %% [markdown]
# ### Cleaning the data we have

# %%
cleaned_df = ad_df[['auction_id', 'experiment', 'yes', 'no']]
not_ans_df = cleaned_df.query("yes == 0 & no == 0")
not_ans_df
# Out:
#                                 auction_id experiment  yes  no
# 0     0008ef63-77a7-448b-bd1e-075f42c55e39    exposed    0   0
# 1     000eabc5-17ce-4137-8efe-44734d914446    exposed    0   0
# 3     00187412-2932-4542-a8ef-3633901c98d9    control    0   0
# 4     001a7785-d3fe-4e11-a344-c8735acacc2c    control    0   0
# 5     0027ce48-d3c6-4935-bb12-dfb5d5627857    control    0   0
# ...                                    ...        ...  ...  ..
# 8072  ffea24ec-cec1-43fb-b1d1-8f93828c2be2    exposed    0   0
# 8073  ffea3210-2c3e-426f-a77d-0aa72e73b20f    control    0   0
# 8074  ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7    control    0   0
# 8075  ffeeed62-3f7c-4a6e-8ba7-95d303d40969    exposed    0   0
# 8076  fffbb9ff-568a-41a5-a0c3-6866592f80d8    control    0   0
#
# [6834 rows x 4 columns]

# %%
print(f"The number of users that did not respond is {not_ans_df.shape[0]} ")
print(f"The percentage of users that did not respond is {(not_ans_df.shape[0] / ad_df.shape[0]) * 100:0.2f}% ")
# Out:
# The number of users that did not respond is 6834
# The percentage of users that did not respond is 84.61%

# %% [markdown]
# Around 85 percent of our users did not respond to the questioner. that is a real disadvantage

# %%
cleaned_df = cleaned_df.query("not (yes == 0 & no == 0)")
cleaned_df.groupby("experiment").agg({"yes": "sum", "no":"sum"})

cleaned_df_agg = cleaned_df.groupby("experiment").agg({"yes": "sum", "no":"sum"})
cleaned_df_agg['aware'] = [0,0]
cleaned_df_agg['aware']['control'] = cleaned_df_agg['yes']['control']
cleaned_df_agg['aware']['exposed'] = cleaned_df_agg['yes']['exposed']

cleaned_df_agg['total'] = [0, 0]
cleaned_df_agg['total']['control'] = cleaned_df_agg['yes']['control'] +  cleaned_df_agg['no']['control']
cleaned_df_agg['total']['exposed'] = cleaned_df_agg['yes']['exposed'] + cleaned_df_agg['no']['exposed']

print(f"number of people that are aware of the brand lux in control group are: {cleaned_df_agg['aware']['control']}")
print(f"number of people that are aware of the brand lux in exposed group are: {cleaned_df_agg['aware']['exposed']}")

test_df = cleaned_df_agg.copy()
test_df
# Out:
# number of people that are aware of the brand lux in control group are: 264
# number of people that are aware of the brand lux in exposed group are: 308
#             yes   no  aware  total
# experiment
# control     264  322    264    586
# exposed     308  349    308    657

# %% [markdown]
# Number of people that are aware of the brand lux in control group are: 264
#
# Number of people that are aware of the brand lux in exposed group are: 308

# %% [markdown]
# ### calculating the conversion rate

# %% [markdown]
# Our metrics is a conversion rate for awareness / total

# %%
control_conversion_rate = test_df['aware']['control'] / test_df['total']['control']
exposed_conversion_rate = test_df['aware']['exposed'] / test_df['total']['exposed']

print(f" The conversion rate of control group is {control_conversion_rate:0.2f}")
print(f" The conversion rate of exposed group is {exposed_conversion_rate:0.2f}")
# Out:
#  The conversion rate of control group is 0.45
#  The conversion rate of exposed group is 0.47

# %% [markdown]
# ### calculating the variance of the control group and exposed group

# %%
diff = exposed_conversion_rate - control_conversion_rate

variance_contorl = control_conversion_rate * (1 - control_conversion_rate)
variance_exposed = exposed_conversion_rate * (1 - exposed_conversion_rate)

# %% [markdown]
# ### calculating the standard error for sampling distribution of the contorl group and exposed group

# %%
control_total = cleaned_df_agg['total']['control']
exposed_total = cleaned_df_agg['total']['exposed']

standar_err_control = np.sqrt(variance_contorl)/np.sqrt(control_total)
standar_err_exposed = np.sqrt(variance_exposed)/np.sqrt(exposed_total)

# %% [markdown]
# ### Calculating the shift in awareness

# %%
shift  = (exposed_conversion_rate - control_conversion_rate) / control_conversion_rate

# %%
fig, ax = plt.subplots(figsize=(15,7))

x = np.linspace(0.3, 0.6, 1000)

ctr_rate_prob = scs.norm(control_conversion_rate, standar_err_control).pdf(x)
ax.plot(x, ctr_rate_prob, label='Control')
ax.axvline(x=control_conversion_rate, c='blue', linestyle='--')



exposed_rate_prob = scs.norm(exposed_conversion_rate, standar_err_exposed).pdf(x)
ax.plot(x, exposed_rate_prob, label='Control')
ax.axvline(x=exposed_conversion_rate, c='red', linestyle='--')
plt.legend()

# %% [markdown]
# #### The graph shows that the awarness has been shifted to the left for the exposed group

# %%
print(f"The awareness of the exposed group has been shifted/increased by {shift * 100:0.2f}%" )
# Out:
# The awareness of the exposed group has been shifted/increased by 4.06%

# %% [markdown]
# ### Conducting the null hypothesis test to check if the increase in awareness is siginificant

# %%
def is_significant(A_rate, B_rate, A_total, B_total, alpha=0.05, tail="one"):
    diff = B_rate - A_rate
    
    A_variance =  A_rate * (1 - A_rate)
    B_variance  = B_rate * (1 - B_rate)
    
    z_score = diff / np.sqrt((A_variance/A_total) + (B_variance/B_total))

    p_value  = scs.norm().sf(z_score)
    
    if (tail == "one"):
        compare = alpha
    else:
        comapre = alpha / 2
        
    return abs(p_value) < alpha, p_value, z_score

# %%
alpha = 1 - 0.95

is_signi, p_value, z_score = is_significant(control_conversion_rate, exposed_conversion_rate,
                                            controll_num, exposed_total, alpha=alpha)


z_score = diff / np.sqrt((variance_contorl/controll_num) + (variance_exposed/exposed_total))
print (f"the calculated z score is {z_score:0.2f}" )

p_value  = scs.norm().sf(z_score)
print (f"the calculated p value is {p_value:0.2f}" )

is_signi, p_value, z_score = is_significant(control_conversion_rate, exposed_conversion_rate,
                                            controll_num, exposed_total)

print(f"Is the value significant: {is_signi}")
# Out:
# the calculated z score is 0.87
# the calculated p value is 0.19
# Is the value significant: False

# %% [markdown]
# The p vaue is telling us that the probablity of seeing this increase in awareness in our exposed group is 26%, but to say the increase in awareness is significant we needed the probablity to be as below as 5%
#
# The confidence interval can be calulated by 100% - 26% = 74%. So 74% of the time the exposed group is going to have the same awareness as the control group
#
# ​
